# %% [markdown]
# ## Question 1: Happiness

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import string
import time
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AgglomerativeClustering

# %%
# read data
data2015original = pd.read_csv("https://raw.githubusercontent.com/sauchilee/Stat517/master/Data/World_Happiness_2015.csv")
data2016original = pd.read_csv("https://raw.githubusercontent.com/sauchilee/Stat517/master/Data/World_Happiness_2016.csv")
data2017original = pd.read_csv("https://raw.githubusercontent.com/sauchilee/Stat517/master/Data/World_Happiness_2017.csv")

# %%
data2015 = data2015original
data2016 = data2016original
data2017 = data2017original

# preprocess data

#drop country name because it's not a useful feature
#drop happiness features because it's the output
data2015 = data2015.drop(['Country', 'Happiness Rank', 'Happiness Score', 'Standard Error'], axis=1)
data2016 = data2016.drop(['Country', 'Happiness Rank', 'Happiness Score', 'Lower Confidence Interval', 'Upper Confidence Interval'], axis=1)
data2017 = data2017.drop(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high', 'Whisker.low'], axis=1)
#convert region to categorical indicators using get_dummies
data2015 = pd.get_dummies(data2015, columns=['Region'])
data2016 = pd.get_dummies(data2016, columns=['Region'])

# %% [markdown]
# ## Preliminary Visualization

# %%
#Premilinary visualization on 2015 data
titles = data2015.axes[1]
f, ax = plt.subplots(7, 7, figsize=(20, 20), sharex='col', sharey='row')
for m in range(6):
    for n in range(m+1, 7):
        ax[m,n].scatter(data2015[titles[n]], data2015[titles[m]])
        ax[m,n].set(xlabel=titles[m], ylabel=titles[n])
#        cell.set_ylabel(titles[j])
#        #ax[m,n].xlabel(titles[n])
#        #ax[m,n].ylabel(titles[m])
#for i, row in enumerate(ax):
#    for j, cell in enumerate(row):
#        cell.set_xlabel(titles[i])
#        cell.set_ylabel(titles[j])
        
print (data2015.shape)
plt.show()
# Out:
# (158, 17)

# %% [markdown]
# We can see that there is correlation between economy and family size, and economy and life expectancy. Other correlations appear to be less strong.

# %%
#visualization on 2016data
titles = data2016.axes[1]
f, ax = plt.subplots(7, 7, figsize=(20, 20), sharex='col', sharey='row')
for m in range(6):
    for n in range(m+1, 7):
        ax[m,n].scatter(data2016[titles[n]], data2016[titles[m]])
        ax[m,n].set(xlabel=titles[m], ylabel=titles[n])
#        cell.set_ylabel(titles[j])
#        #ax[m,n].xlabel(titles[n])
#        #ax[m,n].ylabel(titles[m])
#for i, row in enumerate(ax):
#    for j, cell in enumerate(row):
#        cell.set_xlabel(titles[i])
#        cell.set_ylabel(titles[j])
        
print (data2016.shape)
plt.show()
# Out:
# (157, 17)

# %%
#Premilinary visualization on 2017 data
titles = data2017.axes[1]
f, ax = plt.subplots(7, 7, figsize=(20, 20), sharex='col', sharey='row')
for m in range(6):
    for n in range(m+1, 7):
        ax[m,n].scatter(data2017[titles[n]], data2017[titles[m]])
        ax[m,n].set(xlabel=titles[m], ylabel=titles[n])
#        cell.set_ylabel(titles[j])
#        #ax[m,n].xlabel(titles[n])
#        #ax[m,n].ylabel(titles[m])
#for i, row in enumerate(ax):
#    for j, cell in enumerate(row):
#        cell.set_xlabel(titles[i])
#        cell.set_ylabel(titles[j])
        
print (data2017.shape)
plt.show()
# Out:
# (155, 7)

# %% [markdown]
# ## PCA Dimension Reduction

# %%
#PCA Dimension on 2015 data
pca = PCA().fit(data2015)
ratios = np.cumsum(pca.explained_variance_ratio_)
#ratios = temp/(np.arange(len(temp))+1)
maxRatioIndex = 0
for n in range(1,len(ratios)):
    if ratios[n]/(n/len(ratios)+1) > ratios[maxRatioIndex]/(maxRatioIndex/len(ratios)+1):
        maxRatioIndex = n
#ratios = sorted(ratios)
plt.plot (ratios)
print ("The number of principle components with the highest ratio of variance to components is", maxRatioIndex)
print ("Using", maxRatioIndex, "components will preserve", str(100*ratios[maxRatioIndex].round(4)) + "% of the data")
plt.show()
pca = PCA(n_components=maxRatioIndex)
pca.fit(data2015)
data2015 = pca.transform(data2015)
print (data2015.shape)
# Out:
# The number of principle components with the highest ratio of variance to components is 6
# Using 6 components will preserve 88.52% of the data
# (158, 6)

# %%
plt.scatter([n[0] for n in data2015],[n[1] for n in data2015])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %%
#pca reduction on data2016
pca = PCA().fit(data2016)
ratios = np.cumsum(pca.explained_variance_ratio_)
#ratios = temp/(np.arange(len(temp))+1)
maxRatioIndex = 0
for n in range(1,len(ratios)):
    if ratios[n]/(n/len(ratios)+1) > ratios[maxRatioIndex]/(maxRatioIndex/len(ratios)+1):
        maxRatioIndex = n
#ratios = sorted(ratios)
plt.plot (ratios)
print ("The number of principle components with the highest ratio of variance to components is", maxRatioIndex)
print ("Using", maxRatioIndex, "components will preserve", str(100*ratios[maxRatioIndex].round(4)) + "% of the data")
plt.show()
pca = PCA(n_components=maxRatioIndex)
pca.fit(data2016)
data2016 = pca.transform(data2016)
print (data2016.shape)
# Out:
# The number of principle components with the highest ratio of variance to components is 6
# Using 6 components will preserve 88.49000000000001% of the data
# (157, 6)

# %%
#PCA Dimension on 2017 data
pca = PCA().fit(data2015)
ratios = np.cumsum(pca.explained_variance_ratio_)
#ratios = temp/(np.arange(len(temp))+1)
maxRatioIndex = 0
for n in range(1,len(ratios)):
    if ratios[n]/(n/len(ratios)+1) > ratios[maxRatioIndex]/(maxRatioIndex/len(ratios)+1):
        maxRatioIndex = n
#ratios = sorted(ratios)
plt.plot (ratios)
print ("The number of principle components with the highest ratio of variance to components is", maxRatioIndex)
print ("Using", maxRatioIndex, "components will preserve", str(100*ratios[maxRatioIndex].round(4)) + "% of the data")
plt.show()
pca = PCA(n_components=maxRatioIndex)
pca.fit(data2015)
data2015 = pca.transform(data2015)
print (data2015.shape)

# %% [markdown]
# ## KMeans

# %%
plt.figure(figsize=(20,20))
for numClusters in range(2, 8):
    plt.subplot(3,2,numClusters-1)
    kmeans = KMeans(n_clusters=numClusters, random_state=int(time.time()))
    kmeans.fit(data2015)
    labels = kmeans.predict(data2015)
    plt.xlabel('Principle Component 1')
    plt.ylabel('Principle Component 2')
    plt.scatter(data2015[:, 0], data2015[:, 1], c=labels, marker="o", s=40, cmap='viridis')
plt.show()

# %%
kmeans = KMeans(n_clusters=len(data2015), random_state=int(time.time()))
kmeans.fit(data2015)
labels = kmeans.predict(data2015)
data2015original['kmeans'] = labels

# %% [markdown]
# ## GMM

# %%
plt.figure(figsize=(20,20))
for numComponents in range(2, 8):
    plt.subplot(3,2,numComponents-1)
    gmm = GaussianMixture(n_components=numComponents, covariance_type='full').fit(data2015)
    gmm.fit(data2015)
    labels = gmm.predict(data2015)
    plt.xlabel('Principle Component 1')
    plt.ylabel('Principle Component 2')
    plt.scatter(data2015[:, 0], data2015[:, 1], c=labels, marker="^", s=40, cmap='viridis')
plt.show()

# %%
gmm = GaussianMixture(n_components=len(data2015), covariance_type='full').fit(data2015)
gmm.fit(data2015)
labels = gmm.predict(data2015)
data2015original['gmm'] = labels

# %% [markdown]
# ## AgglomerativeClusutering

# %%
plt.figure(figsize=(20,20))
for numClusters in range(2, 8):
    plt.subplot(3,2,numClusters-1)
    cluster = AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto', connectivity=None, linkage='ward', memory=None, n_clusters=numClusters, pooling_func='deprecated')
    labels = cluster.fit_predict(data2015)
    plt.xlabel('Principle Component 1')
    plt.ylabel('Principle Component 2')
    plt.scatter(data2015[:, 0], data2015[:, 1], c=labels, marker="s", s=40, cmap='viridis')
plt.show()

# %%
agglo = AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto', connectivity=None, linkage='ward', memory=None, n_clusters=len(data2015), pooling_func='deprecated')
labels = agglo.fit_predict(data2015)
data2015original['agglo'] = labels

# %% [markdown]
# ## Spectral Clustering

# %%
plt.figure(figsize=(20,20))
for numClusters in range(2, 8):
    plt.subplot(3,2,numClusters-1)
    cluster = SpectralClustering(n_clusters=numClusters, affinity='nearest_neighbors', assign_labels='kmeans')
    labels = cluster.fit_predict(data2015)
    plt.xlabel('Principle Component 1')
    plt.ylabel('Principle Component 2')
    plt.scatter(data2015[:, 0], data2015[:, 1], c=labels, marker="*", s=40, cmap='viridis')
plt.show()

# %% [markdown]
# ## Agglomerative Seriation

# %% [markdown]
# Since we already clustered with numClusters equal to the number of countries, we simply rank the countries by which cluster they are in.

# %%
data2015original.nlargest(20,'agglo')
# Out:
#                 Country                       Region  Happiness Rank  \
# 50              Bolivia  Latin America and Caribbean              51
# 24               Panama  Latin America and Caribbean              25
# 0           Switzerland               Western Europe               1
# 40  Trinidad and Tobago  Latin America and Caribbean              41
# 8           New Zealand    Australia and New Zealand               9
# 31              Uruguay  Latin America and Caribbean              32
# 47              Ecuador  Latin America and Caribbean              48
# 2               Denmark               Western Europe               3
# 6           Netherlands               Western Europe               7
# 20       United Kingdom               Western Europe              21
# 4                Canada                North America               5
# 44             Slovakia   Central and Eastern Europe              45
# 25              Germany               Western Europe              26
# 3                Norway               Western Europe               4
# 17              Ireland               Western Europe              18
# 15               Brazil  Latin America and Caribbean              16
# 1               Iceland               Western Europe               2
# 7                Sweden               Western Europe               8
# 54             Slovenia   Central and Eastern Europe              55
# 29            Argentina  Latin America and Caribbean              30
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 50            5.890         0.05642                   0.68133  0.97841
# 24            6.786         0.04910                   1.06353  1.19850
# 0             7.587         0.03411                   1.39651  1.34951
# 40            6.168         0.10895                   1.21183  1.18354
# 8             7.286         0.03371                   1.25018  1.31967
# 31            6.485         0.04539                   1.06166  1.20890
# 47            5.975         0.04528                   0.86402  0.99903
# 2             7.527         0.03328                   1.32548  1.36058
# 6             7.378         0.02799                   1.32944  1.28017
# 20            6.867         0.01866                   1.26637  1.28548
# 4             7.427         0.03553                   1.32629  1.32261
# 44            5.995         0.04267                   1.16891  1.26999
# 25            6.750         0.01848                   1.32792  1.29937
# 3             7.522         0.03880                   1.45900  1.33095
# 17            6.940         0.03676                   1.33596  1.36948
# 15            6.983         0.04076                   0.98124  1.23287
# 1             7.561         0.04884                   1.30232  1.40223
# 7             7.364         0.03157                   1.33171  1.28907
# 54            5.848         0.04251                   1.18498  1.27385
# 29            6.574         0.04612                   1.05351  1.24823
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 50                   0.53920  0.57414                        0.08800
# 24                   0.79661  0.54210                        0.09270
# 0                    0.94143  0.66557                        0.41978
# 40                   0.61483  0.55884                        0.01140
# 8                    0.90837  0.63938                        0.42922
# 31                   0.81160  0.60362                        0.24558
# 47                   0.79075  0.48574                        0.18090
# 2                    0.87464  0.64938                        0.48357
# 6                    0.89284  0.61576                        0.31814
# 20                   0.90943  0.59625                        0.32067
# 4                    0.90563  0.63297                        0.32957
# 44                   0.78902  0.31751                        0.03431
# 25                   0.89186  0.61477                        0.21843
# 3                    0.88521  0.66973                        0.36503
# 17                   0.89533  0.61777                        0.28703
# 15                   0.69702  0.49049                        0.17521
# 1                    0.94784  0.62877                        0.14145
# 7                    0.91087  0.65980                        0.43844
# 54                   0.87337  0.60855                        0.03787
# 29                   0.78723  0.44974                        0.08484
#
#     Generosity  Dystopia Residual  kmeans  gmm  agglo
# 50     0.20536            2.82334      56  127    157
# 24     0.24434            2.84848     156  156    156
# 0      0.29678            2.51738      68  155    155
# 40     0.31844            2.26882     152   71    154
# 8      0.47501            2.26425     153  154    153
# 31     0.23240            2.32142      61  152    152
# 47     0.11541            2.53942       8   87    151
# 2      0.34139            2.49204     140  150    150
# 6      0.47610            2.46570     149  149    149
# 20     0.51912            1.96994      96  139    148
# 4      0.45811            2.45176       0  146    147
# 44     0.16893            2.24639     145  145    146
# 25     0.28214            2.11569      58   79    145
# 3      0.34699            2.46531     155   94    144
# 17     0.45901            1.97570     144  102    143
# 15     0.14574            3.26001     112   11    142
# 1      0.43630            2.70201      91   64    141
# 7      0.36262            2.37119     143  144    140
# 54     0.25328            1.61583      93   90    139
# 29     0.11451            2.83600     103   45    138

# %%
data2015original.nsmallest(20,'agglo')
# Out:
#           Country                           Region  Happiness Rank  \
# 157          Togo               Sub-Saharan Africa             158
# 156       Burundi               Sub-Saharan Africa             157
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 152   Afghanistan                    Southern Asia             153
# 151  Burkina Faso               Sub-Saharan Africa             152
# 129       Georgia       Central and Eastern Europe             130
# 150   Ivory Coast               Sub-Saharan Africa             151
# 153        Rwanda               Sub-Saharan Africa             154
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 130        Malawi               Sub-Saharan Africa             131
# 146    Madagascar               Sub-Saharan Africa             147
# 128       Myanmar                Southeastern Asia             129
# 124         Kenya               Sub-Saharan Africa             125
# 143         Niger               Sub-Saharan Africa             144
# 141       Senegal               Sub-Saharan Africa             142
# 145      Tanzania               Sub-Saharan Africa             146
# 139       Comoros               Sub-Saharan Africa             140
# 142         Gabon               Sub-Saharan Africa             143
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 157            2.839         0.06727                   0.20868  0.13995
# 156            2.905         0.08658                   0.01530  0.41587
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 152            3.575         0.03084                   0.31982  0.30285
# 151            3.587         0.04324                   0.25812  0.85188
# 129            4.297         0.04221                   0.74190  0.38562
# 150            3.655         0.05141                   0.46534  0.77115
# 153            3.465         0.03464                   0.22208  0.77370
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# 130            4.292         0.06130                   0.01604  0.41134
# 146            3.681         0.03633                   0.20824  0.66801
# 128            4.307         0.04351                   0.27108  0.70905
# 124            4.419         0.04734                   0.36471  0.99876
# 143            3.845         0.03602                   0.06940  0.77265
# 141            3.904         0.03608                   0.36498  0.97619
# 145            3.781         0.05061                   0.28520  1.00268
# 139            3.956         0.04797                   0.23906  0.79273
# 142            3.896         0.04547                   1.06024  0.90528
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 157                   0.28443  0.36453                        0.10731
# 156                   0.22396  0.11850                        0.10062
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 152                   0.30335  0.23414                        0.09719
# 151                   0.27125  0.39493                        0.12832
# 129                   0.72926  0.40577                        0.38331
# 150                   0.15185  0.46866                        0.17922
# 153                   0.42864  0.59201                        0.55191
# 148                   0.15010  0.23501                        0.05269
# 149                   0.24009  0.37725                        0.12139
# 130                   0.22562  0.43054                        0.06977
# 146                   0.46721  0.19184                        0.08124
# 128                   0.48246  0.44017                        0.19034
# 124                   0.41435  0.42215                        0.05839
# 143                   0.29707  0.47692                        0.15639
# 141                   0.43540  0.36772                        0.10713
# 145                   0.38215  0.32878                        0.05747
# 139                   0.36315  0.22917                        0.19900
# 142                   0.43372  0.31914                        0.11091
#
#      Generosity  Dystopia Residual  kmeans  gmm  agglo
# 157     0.16681            1.56726      29    1      0
# 156     0.19727            1.83302      99   70      1
# 154     0.18260            1.63328     105  101      2
# 155     0.47179            0.32858      19   18      3
# 152     0.36510            1.95210      31    8      4
# 151     0.21747            1.46494     134  136      5
# 129     0.05547            1.59541      79   89      6
# 150     0.20165            1.41723      39   32      7
# 153     0.22628            0.67042      34   34      8
# 148     0.18386            1.94296     157   50      9
# 149     0.28657            1.99172      73   99     10
# 130     0.33128            2.80791      95   93     11
# 146     0.21333            1.85100      90  133     12
# 128     0.79588            1.41805      62   51     13
# 124     0.37542            1.78555     115  116     14
# 143     0.19387            1.87877     133  107     15
# 141     0.20843            1.44395     118  122     16
# 145     0.34377            1.38079     148  148     17
# 139     0.17441            1.95812       1  157     18
# 142     0.06822            0.99895      10    9     19

# %% [markdown]
# ## KMeans Seriation

# %%
data2015original.nlargest(20,'kmeans')
# Out:
#                  Country                           Region  Happiness Rank  \
# 148                 Chad               Sub-Saharan Africa             149
# 24                Panama      Latin America and Caribbean              25
# 3                 Norway                   Western Europe               4
# 79            Azerbaijan       Central and Eastern Europe              80
# 8            New Zealand        Australia and New Zealand               9
# 40   Trinidad and Tobago      Latin America and Caribbean              41
# 12               Austria                   Western Europe              13
# 57                  Peru      Latin America and Caribbean              58
# 6            Netherlands                   Western Europe               7
# 145             Tanzania               Sub-Saharan Africa             146
# 35                 Spain                   Western Europe              36
# 14         United States                    North America              15
# 44              Slovakia       Central and Eastern Europe              45
# 17               Ireland                   Western Europe              18
# 7                 Sweden                   Western Europe               8
# 34          Saudi Arabia  Middle East and Northern Africa              35
# 72               Estonia       Central and Eastern Europe              73
# 2                Denmark                   Western Europe               3
# 22             Venezuela      Latin America and Caribbean              23
# 140               Uganda               Sub-Saharan Africa             141
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 24             6.786         0.04910                   1.06353  1.19850
# 3              7.522         0.03880                   1.45900  1.33095
# 79             5.212         0.03363                   1.02389  0.93793
# 8              7.286         0.03371                   1.25018  1.31967
# 40             6.168         0.10895                   1.21183  1.18354
# 12             7.200         0.03751                   1.33723  1.29704
# 57             5.824         0.04615                   0.90019  0.97459
# 6              7.378         0.02799                   1.32944  1.28017
# 145            3.781         0.05061                   0.28520  1.00268
# 35             6.329         0.03468                   1.23011  1.31379
# 14             7.119         0.03839                   1.39451  1.24711
# 44             5.995         0.04267                   1.16891  1.26999
# 17             6.940         0.03676                   1.33596  1.36948
# 7              7.364         0.03157                   1.33171  1.28907
# 34             6.411         0.04633                   1.39541  1.08393
# 72             5.429         0.04013                   1.15174  1.22791
# 2              7.527         0.03328                   1.32548  1.36058
# 22             6.810         0.06476                   1.04424  1.25596
# 140            3.931         0.04317                   0.21102  1.13299
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 148                   0.15010  0.23501                        0.05269
# 24                    0.79661  0.54210                        0.09270
# 3                     0.88521  0.66973                        0.36503
# 79                    0.64045  0.37030                        0.16065
# 8                     0.90837  0.63938                        0.42922
# 40                    0.61483  0.55884                        0.01140
# 12                    0.89042  0.62433                        0.18676
# 57                    0.73017  0.41496                        0.05989
# 6                     0.89284  0.61576                        0.31814
# 145                   0.38215  0.32878                        0.05747
# 35                    0.95562  0.45951                        0.06398
# 14                    0.86179  0.54604                        0.15890
# 44                    0.78902  0.31751                        0.03431
# 17                    0.89533  0.61777                        0.28703
# 7                     0.91087  0.65980                        0.43844
# 34                    0.72025  0.31048                        0.32524
# 72                    0.77361  0.44888                        0.15184
# 2                     0.87464  0.64938                        0.48357
# 22                    0.72052  0.42908                        0.11069
# 140                   0.33861  0.45727                        0.07267
#
#      Generosity  Dystopia Residual  kmeans  gmm  agglo
# 148     0.18386            1.94296     157   50      9
# 24      0.24434            2.84848     156  156    156
# 3       0.34699            2.46531     155   94    144
# 79      0.07799            2.00073     154  153     76
# 8       0.47501            2.26425     153  154    153
# 40      0.31844            2.26882     152   71    154
# 12      0.33088            2.53320     151  129    126
# 57      0.14982            2.59450     150  151     53
# 6       0.47610            2.46570     149  149    149
# 145     0.34377            1.38079     148  148     17
# 35      0.18227            2.12367     147  143    118
# 14      0.40105            2.51011     146   75     98
# 44      0.16893            2.24639     145  145    146
# 17      0.45901            1.97570     144  102    143
# 7       0.36262            2.37119     143  144    140
# 34      0.13706            2.43872     142  140     80
# 72      0.08680            1.58782     141  135     50
# 2       0.34139            2.49204     140  150    150
# 22      0.05841            3.19131     139  142    104
# 140     0.29066            1.42766     138  138     36

# %%
data2015original.nsmallest(20,'kmeans')
# Out:
#                  Country                           Region  Happiness Rank  \
# 4                 Canada                    North America               5
# 139              Comoros               Sub-Saharan Africa             140
# 88                Latvia       Central and Eastern Europe              89
# 73             Indonesia                Southeastern Asia              74
# 81                Jordan  Middle East and Northern Africa              82
# 11            Costa Rica      Latin America and Caribbean              12
# 16            Luxembourg                   Western Europe              17
# 76            Kyrgyzstan       Central and Eastern Europe              77
# 47               Ecuador      Latin America and Caribbean              48
# 108           Bangladesh                    Southern Asia             109
# 142                Gabon               Sub-Saharan Africa             143
# 77               Nigeria               Sub-Saharan Africa              78
# 71             Hong Kong                     Eastern Asia              72
# 138  Congo (Brazzaville)               Sub-Saharan Africa             139
# 144             Cambodia                Southeastern Asia             145
# 67               Algeria  Middle East and Northern Africa              68
# 51               Moldova       Central and Eastern Europe              52
# 18               Belgium                   Western Europe              19
# 99              Mongolia                     Eastern Asia             100
# 155                Syria  Middle East and Northern Africa             156
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 4              7.427         0.03553                   1.32629  1.32261
# 139            3.956         0.04797                   0.23906  0.79273
# 88             5.098         0.04640                   1.11312  1.09562
# 73             5.399         0.02596                   0.82827  1.08708
# 81             5.192         0.04524                   0.90198  1.05392
# 11             7.226         0.04454                   0.95578  1.23788
# 16             6.946         0.03499                   1.56391  1.21963
# 76             5.286         0.03823                   0.47428  1.15115
# 47             5.975         0.04528                   0.86402  0.99903
# 108            4.694         0.03077                   0.39753  0.43106
# 142            3.896         0.04547                   1.06024  0.90528
# 77             5.268         0.04192                   0.65435  0.90432
# 71             5.474         0.05051                   1.38604  1.05818
# 138            3.989         0.06682                   0.67866  0.66290
# 144            3.819         0.05069                   0.46038  0.62736
# 67             5.605         0.05099                   0.93929  1.07772
# 51             5.889         0.03799                   0.59448  1.01528
# 18             6.937         0.03595                   1.30782  1.28566
# 99             4.874         0.03313                   0.82819  1.30060
# 155            3.006         0.05015                   0.66320  0.47489
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 4                     0.90563  0.63297                        0.32957
# 139                   0.36315  0.22917                        0.19900
# 88                    0.72437  0.29671                        0.06332
# 73                    0.63793  0.46611                        0.00000
# 81                    0.69639  0.40661                        0.14293
# 11                    0.86027  0.63376                        0.10583
# 16                    0.91894  0.61583                        0.37798
# 76                    0.65088  0.43477                        0.04232
# 47                    0.79075  0.48574                        0.18090
# 108                   0.60164  0.40820                        0.12569
# 142                   0.43372  0.31914                        0.11091
# 77                    0.16007  0.34334                        0.04030
# 71                    1.01328  0.59608                        0.37124
# 138                   0.31051  0.41466                        0.11686
# 144                   0.61114  0.66246                        0.07247
# 67                    0.61766  0.28579                        0.17383
# 51                    0.61826  0.32818                        0.01615
# 18                    0.89667  0.58450                        0.22540
# 99                    0.60268  0.43626                        0.02666
# 155                   0.72193  0.15684                        0.18906
#
#      Generosity  Dystopia Residual  kmeans  gmm  agglo
# 4       0.45811            2.45176       0  146    147
# 139     0.17441            1.95812       1  157     18
# 88      0.18226            1.62215       2   38     48
# 73      0.51535            1.86399       3  123    112
# 81      0.11053            1.87996       4   78     51
# 11      0.25497            3.17728       5  124    129
# 16      0.28034            1.96961       6   60    106
# 76      0.30030            2.23270       7   52     44
# 47      0.11541            2.53942       8   87    151
# 108     0.21222            2.51767       9   20     83
# 142     0.06822            0.99895      10    9     19
# 77      0.27233            2.89319      11    6     55
# 71      0.39478            0.65429      12   24     87
# 138     0.12388            1.68135      13   83     22
# 144     0.40359            0.98195      14   37     20
# 67      0.07822            2.43209      15   40     72
# 51      0.20951            3.10712      16   62    113
# 18      0.22250            2.41484      17   14     81
# 99      0.33230            1.34759      18   29     49
# 155     0.47179            0.32858      19   18      3

# %% [markdown]
# ## Conclusion

# %% [markdown]
# A. Without using any "Happiness" information given, conduct proper Clusterings Analyses and describe these clusters.
#
# B. Without using any "Happiness" information given, conduct proper Seriation Analyses and compare the generated order with the "Happiness" ranking.
#
# C. Report your findings, including investigations and discussions to support or reflute the following remarks:
#
# 1) Norway tops the global happiness rankings for all three years 2015, 2016, and 2017
#
#  2) All top ten countries rank highly on all the main features found to support happiness
#
#  3) Happiness is both social and personal
#
#  4) Unemployment causes a major fall in happiness, and even for those in work the quality of work can cause major variations in happiness
#
#  5) China are no happier than most countries, though richer and longer longevity
#
#  6) Much of Africa is struggling
#
#  7) Happiness has fallen in America
